# %% [markdown]
# # Setup

# %%
# !apt-get update
# !curl -o- https://raw.githubusercontent.com/nvm-sh/nvm/v0.39.7/install.sh | bash
# !source ~/.bashrc
# !nvm install 19.1.0
# !nvm use 19.1.0
# !git clone -b v2-uplift https://github.com/thasan01/tic-tac-toe-machine-learning.git

# %cd ./tic-tac-toe-machine-learning
# !npm install --prefix ./game
# !npm run build --prefix ./game

# %% [markdown]
# # Training

# %%
# 1. Set the working directory to the project root, as the script requires.
# %cd /content/tic-tac-toe-machine-learning

import os
from google.colab import drive

# Mount the Google Drive
drive.mount('/content/drive')
drive_base_dir = '/content/drive/My Drive/ai-training/t3'
model_dir = f'{drive_base_dir}/models'
log_dir = '/tmp/t3/logs'
data_dir = '/tmp/t3/sessions'

# Create local dir if they dont exists
# !mkdir -p $data_dir
# !mkdir -p $log_dir

# 2. Add the 'ai-agent' directory to Python's module search path.
os.environ['PYTHONPATH'] = '/content/tic-tac-toe-machine-learning/ai-agent'

# 3. Run the script from the project root. Python will now find the module.
# !python ai-agent/src/t3train.py "$data_dir" "$log_dir" "$model_dir"

# !cp -r $log_dir $drive_base_dir/logs
